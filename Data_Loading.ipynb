# %%
import pandas as pd
import numpy as np

# %%
ewaste = pd.read_csv(r"C:\Users\Admin\Desktop\IIMSTC\MINI PROJECT\E_Waste_Prediction_Project\ewaste_2019_2025_cleaned.csv")
gni = pd.read_csv(r"C:\Users\Admin\Desktop\IIMSTC\MINI PROJECT\E_Waste_Prediction_Project\gni_2019_2025_cleaned.csv")
internet = pd.read_csv(r"C:\Users\Admin\Desktop\IIMSTC\MINI PROJECT\E_Waste_Prediction_Project\internet_2019_2025_cleaned.csv")

imports = pd.read_csv(r"C:\Users\Admin\Desktop\IIMSTC\MINI PROJECT\E_Waste_Prediction_Project\electronics_import_value_2019_2025.csv")
gdp_growth = pd.read_csv(r"C:\Users\Admin\Desktop\IIMSTC\MINI PROJECT\E_Waste_Prediction_Project\world_gdp_growth_2019_2025.csv")
urban = pd.read_csv(r"C:\Users\Admin\Desktop\IIMSTC\MINI PROJECT\E_Waste_Prediction_Project\world_urban_population_2019_2025.csv")
population = pd.read_csv(r"C:\Users\Admin\Desktop\IIMSTC\MINI PROJECT\E_Waste_Prediction_Project\world_population_2019_2025.csv")

print("All datasets loaded successfully.")
# Out:
# All datasets loaded successfully.

# %%
print("E-waste:")
print(ewaste.head())
print("\nGNI:")
print(gni.head())
print("\nInternet Penetration:")
print(internet.head())  
print("\nElectronics Import Value:")
print(imports.head())   
print("\nWorld GDP Growth:")
print(gdp_growth.head())        
print("\nUrban Population:")
print(urban.head())
print("\nTotal Population:")
print(population.head())
# Out:
# E-waste:
#        Country  Year  E_Waste_per_capita
# 0  Afghanistan  2019               0.600
# 1  Afghanistan  2020               0.632
# 2  Afghanistan  2021               0.665
# 3  Afghanistan  2022               0.700
# 4  Afghanistan  2023               0.737
#
# GNI:
#                        Country  Year  GNI_per_capita
# 0                        Aruba  2019    29320.000000
# 1  Africa Eastern and Southern  2019     1501.996953
# 2                  Afghanistan  2019      520.000000
# 3   Africa Western and Central  2019     1784.137169
# 4                       Angola  2019     2440.000000
#
# Internet Penetration:
#                        Country  Year  Internet_Users
# 0  Africa Eastern and Southern  2019         21.6000
# 1                  Afghanistan  2019         17.6000
# 2   Africa Western and Central  2019         28.5000
# 3                       Angola  2019         32.1294
# 4                      Albania  2019         68.5504
#
# Electronics Import Value:
# ...
