# %%
ewaste = ewaste.rename(columns={"E_Waste_per_capita": "E_Waste"})
gni = gni.rename(columns={"GNI_per_capita": "GNI"})
internet = internet.rename(columns={"Internet_Users": "Internet_Users"})
imports = imports.rename(columns={"Import_Value": "Electronics_Imports"})
gdp_growth = gdp_growth.rename(columns={"GDP_Growth": "GDP_Growth"})
urban = urban.rename(columns={"Urban_Population": "Urban_Pop"})
population = population.rename(columns={"Population": "Total_Population"})

# %%
print("E-waste columns:",ewaste.columns)
print("GNI columns:",gni.columns)
print("Internet columns:",internet.columns)
print("Imports columns:",imports.columns)
print("GDP Growth columns:",gdp_growth.columns)
print("Urban Population columns:",urban.columns)
print("Total Population columns:",population.columns)
# Out:
# E-waste columns: Index(['Country', 'Year', 'E_Waste'], dtype='str')
# GNI columns: Index(['Country', 'Year', 'GNI'], dtype='str')
# Internet columns: Index(['Country', 'Year', 'Internet_Users'], dtype='str')
# Imports columns: Index(['Reference area', 'Year', 'Electronic_Import_Value_Billions'], dtype='str')
# GDP Growth columns: Index(['Reference area', 'Year', 'GDP_Growth_Rate_Percent'], dtype='str')
# Urban Population columns: Index(['Reference area', 'Year', 'Urban_Population_Value'], dtype='str')
# Total Population columns: Index(['Reference area', 'Year', 'OBS_VALUE'], dtype='str')

# %%
imports = imports.rename(columns={"Reference area": "Country"})
gdp_growth = gdp_growth.rename(columns={"Reference area": "Country"})
urban = urban.rename(columns={"Reference area": "Country"})
population = population.rename(columns={"Reference area": "Country"})
imports = imports.rename(columns={"Electronic_Import_Value_Billions": "Electronics_Imports"})
gdp_growth = gdp_growth.rename(columns={"GDP_Growth_Rate_Percent": "GDP_Growth"})
urban = urban.rename(columns={"Urban_Population_Value": "Urban_Population"})
population = population.rename(columns={"OBS_VALUE": "Total_Population"})
print("All columns standardized successfully.")
# Out:
# All columns standardized successfully.
